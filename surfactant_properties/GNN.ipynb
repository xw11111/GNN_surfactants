# %%
# train 
# ref: https://chemprop.readthedocs.io/en/latest/cmd.html
import subprocess
# without MDfeautre
n_depths = [2,3,4]
message_hidden_dims = [200,300,400]
ffn_num_layers = [1,2]
ffn_hidden_dims = [200,300,400]
dropouts=[0,0.1,0.2]

# Hyperparameter Tunings
# trial = 0
# for n_depth in n_depths:
#     for message_hidden_dim in message_hidden_dims:
#         for ffn_num_layer in ffn_num_layers:
#             for ffn_hidden_dim in ffn_hidden_dims:
#                 for dropout in dropouts:
#                     command = f"chemprop train --data-path 070324_chemprop_addon.csv --task-type regression --epochs 1000 --num-folds 5 --split CV --save-smiles-splits"
#                     print(trial,command)
#                     trial+=1
#                     subprocess.run(command, shell=True)

# default
# !chemprop train --data-path 062524_chemprop_addon_modifiedF.csv --atom-features-path MDFeatureGen/070124_partialcharge.npz --task-type regression --epochs 1000 --ensemble-size 5 --save-smiles-splits
# !chemprop train \
    --data-path data.csv \
    --task-type regression \
    --epochs 10 \
    --ensemble-size 5 \
    --save-smiles-splits 

    # hyperparameters
    #--depth 4 --message-hidden-dim 200 --ffn-num-layers 1 --ffn-hidden-dim 300 --dropout 0.2
    # MD feature
    # --atom-features-path MDFeatureGen/070124_partialcharge_sigma_epsilon.npz \
    # MD descriptor
    # --descriptors-path MDFeatureGen/070224_surface_area_head_tail.npz \
# Out:
# Wrote config file to chemprop_training\071524_chemprop\2024-11-14T14-20-06\config.toml
#
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking:   0%|          | 0/1 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  8.53it/s]
#
#
# Training: |          | 0/? [00:00<?, ?it/s]
# Training:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 0:  50%|█████     | 1/2 [00:00<00:00,  9.88it/s]
# Epoch 0:  50%|█████     | 1/2 [00:00<00:00,  9.79it/s, v_num=0, train_loss=1.070]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 17.75it/s, v_num=0, train_loss=1.070]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 17.75it/s, v_num=0, train_loss=0.516]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 681.45it/s]
#
#
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 16.35it/s, v_num=0, train_loss=0.516, val_loss=0.867]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 16.35it/s, v_num=0, train_loss=0.516, val_loss=0.867]
# Epoch 0:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.516, val_loss=0.867]
# Epoch 1:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.516, val_loss=0.867]
# Epoch 1:  50%|█████     | 1/2 [00:00<00:00, 25.47it/s, v_num=0, train_loss=0.516, val_loss=0.867]
# Epoch 1:  50%|█████     | 1/2 [00:00<00:00, 25.14it/s, v_num=0, train_loss=0.714, val_loss=0.867]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 38.75it/s, v_num=0, train_loss=0.714, val_loss=0.867]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 38.75it/s, v_num=0, train_loss=0.453, val_loss=0.867]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 405.76it/s]
#
#
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 33.13it/s, v_num=0, train_loss=0.453, val_loss=0.838]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 32.49it/s, v_num=0, train_loss=0.453, val_loss=0.838]
# Epoch 1:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.453, val_loss=0.838]
# Epoch 2:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.453, val_loss=0.838]
# Epoch 2:  50%|█████     | 1/2 [00:00<00:00, 27.76it/s, v_num=0, train_loss=0.453, val_loss=0.838]
# Epoch 2:  50%|█████     | 1/2 [00:00<00:00, 27.76it/s, v_num=0, train_loss=0.538, val_loss=0.838]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 41.24it/s, v_num=0, train_loss=0.538, val_loss=0.838]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 40.41it/s, v_num=0, train_loss=0.603, val_loss=0.838]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 397.56it/s]
#
#
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 33.60it/s, v_num=0, train_loss=0.603, val_loss=0.816]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 33.60it/s, v_num=0, train_loss=0.603, val_loss=0.816]
# Epoch 2:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.603, val_loss=0.816]
# Epoch 3:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.603, val_loss=0.816]
# Epoch 3:  50%|█████     | 1/2 [00:00<00:00, 24.37it/s, v_num=0, train_loss=0.603, val_loss=0.816]
# Epoch 3:  50%|█████     | 1/2 [00:00<00:00, 23.79it/s, v_num=0, train_loss=0.460, val_loss=0.816]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 38.80it/s, v_num=0, train_loss=0.460, val_loss=0.816]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 38.80it/s, v_num=0, train_loss=0.265, val_loss=0.816]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 333.28it/s]
#
#
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 33.30it/s, v_num=0, train_loss=0.265, val_loss=0.810]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 32.76it/s, v_num=0, train_loss=0.265, val_loss=0.810]
# Epoch 3:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.265, val_loss=0.810]
# Epoch 4:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.265, val_loss=0.810]
# Epoch 4:  50%|█████     | 1/2 [00:00<00:00, 28.15it/s, v_num=0, train_loss=0.265, val_loss=0.810]
# Epoch 4:  50%|█████     | 1/2 [00:00<00:00, 27.38it/s, v_num=0, train_loss=0.380, val_loss=0.810]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 43.46it/s, v_num=0, train_loss=0.380, val_loss=0.810]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 43.46it/s, v_num=0, train_loss=0.478, val_loss=0.810]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 399.04it/s]
#
#
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 37.36it/s, v_num=0, train_loss=0.478, val_loss=0.805]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 37.36it/s, v_num=0, train_loss=0.478, val_loss=0.805]
# Epoch 4:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.478, val_loss=0.805]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.478, val_loss=0.805]
# Epoch 5:  50%|█████     | 1/2 [00:00<00:00, 31.68it/s, v_num=0, train_loss=0.478, val_loss=0.805]
# Epoch 5:  50%|█████     | 1/2 [00:00<00:00, 31.68it/s, v_num=0, train_loss=0.360, val_loss=0.805]
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 47.17it/s, v_num=0, train_loss=0.360, val_loss=0.805]
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 47.17it/s, v_num=0, train_loss=0.313, val_loss=0.805]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 224.15it/s]
#
#
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 36.76it/s, v_num=0, train_loss=0.313, val_loss=0.802]
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 36.76it/s, v_num=0, train_loss=0.313, val_loss=0.802]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.313, val_loss=0.802]
# Epoch 6:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.313, val_loss=0.802]
# Epoch 6:  50%|█████     | 1/2 [00:00<00:00, 28.50it/s, v_num=0, train_loss=0.313, val_loss=0.802]
# Epoch 6:  50%|█████     | 1/2 [00:00<00:00, 28.50it/s, v_num=0, train_loss=0.340, val_loss=0.802]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 44.85it/s, v_num=0, train_loss=0.340, val_loss=0.802]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 43.87it/s, v_num=0, train_loss=0.318, val_loss=0.802]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 199.99it/s]
#
#
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 35.65it/s, v_num=0, train_loss=0.318, val_loss=0.801]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 35.02it/s, v_num=0, train_loss=0.318, val_loss=0.801]
# Epoch 6:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.318, val_loss=0.801]
# Epoch 7:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.318, val_loss=0.801]
# Epoch 7:  50%|█████     | 1/2 [00:00<00:00, 27.69it/s, v_num=0, train_loss=0.318, val_loss=0.801]
# Epoch 7:  50%|█████     | 1/2 [00:00<00:00, 27.69it/s, v_num=0, train_loss=0.302, val_loss=0.801]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 43.91it/s, v_num=0, train_loss=0.302, val_loss=0.801]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 43.91it/s, v_num=0, train_loss=0.387, val_loss=0.801]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 500.04it/s]
#
#
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 37.00it/s, v_num=0, train_loss=0.387, val_loss=0.801]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 37.00it/s, v_num=0, train_loss=0.387, val_loss=0.801]
# Epoch 7:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.387, val_loss=0.801]
# Epoch 8:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.387, val_loss=0.801]
# Epoch 8:  50%|█████     | 1/2 [00:00<00:00, 28.55it/s, v_num=0, train_loss=0.387, val_loss=0.801]
# Epoch 8:  50%|█████     | 1/2 [00:00<00:00, 28.55it/s, v_num=0, train_loss=0.313, val_loss=0.801]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 43.92it/s, v_num=0, train_loss=0.313, val_loss=0.801]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 42.97it/s, v_num=0, train_loss=0.194, val_loss=0.801]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 399.08it/s]
#
#
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 35.68it/s, v_num=0, train_loss=0.194, val_loss=0.799]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 35.05it/s, v_num=0, train_loss=0.194, val_loss=0.799]
# Epoch 8:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.194, val_loss=0.799]
# Epoch 9:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.194, val_loss=0.799]
# Epoch 9:  50%|█████     | 1/2 [00:00<00:00, 32.24it/s, v_num=0, train_loss=0.194, val_loss=0.799]
# Epoch 9:  50%|█████     | 1/2 [00:00<00:00, 31.72it/s, v_num=0, train_loss=0.284, val_loss=0.799]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 48.81it/s, v_num=0, train_loss=0.284, val_loss=0.799]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 48.21it/s, v_num=0, train_loss=0.433, val_loss=0.799]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 499.50it/s]
#
#
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 41.25it/s, v_num=0, train_loss=0.433, val_loss=0.797]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 40.41it/s, v_num=0, train_loss=0.433, val_loss=0.797]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 26.31it/s, v_num=0, train_loss=0.433, val_loss=0.797]
#
# Predicting: |          | 0/? [00:00<?, ?it/s]
# Predicting:   0%|          | 0/1 [00:00<?, ?it/s]
# Predicting DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 221.52it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 221.52it/s]
# Entire Test Set results: {'entire_test/mse': 20.936350915407107}
#
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking:   0%|          | 0/1 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 249.87it/s]
#
#
# Training: |          | 0/? [00:00<?, ?it/s]
# Training:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 0:  50%|█████     | 1/2 [00:00<00:00, 28.01it/s]
# Epoch 0:  50%|█████     | 1/2 [00:00<00:00, 28.01it/s, v_num=0, train_loss=1.020]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 43.52it/s, v_num=0, train_loss=1.020]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 43.52it/s, v_num=0, train_loss=0.885]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 498.43it/s]
#
#
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 36.05it/s, v_num=0, train_loss=0.885, val_loss=0.866]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 35.11it/s, v_num=0, train_loss=0.885, val_loss=0.866]
# Epoch 0:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.885, val_loss=0.866]
# Epoch 1:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.885, val_loss=0.866]
# Epoch 1:  50%|█████     | 1/2 [00:00<00:00, 25.86it/s, v_num=0, train_loss=0.885, val_loss=0.866]
# Epoch 1:  50%|█████     | 1/2 [00:00<00:00, 25.86it/s, v_num=0, train_loss=0.646, val_loss=0.866]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 39.63it/s, v_num=0, train_loss=0.646, val_loss=0.866]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 39.63it/s, v_num=0, train_loss=0.308, val_loss=0.866]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 179.55it/s]
#
#
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 32.03it/s, v_num=0, train_loss=0.308, val_loss=0.863]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 32.03it/s, v_num=0, train_loss=0.308, val_loss=0.863]
# Epoch 1:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.308, val_loss=0.863]
# Epoch 2:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.308, val_loss=0.863]
# Epoch 2:  50%|█████     | 1/2 [00:00<00:00, 31.54it/s, v_num=0, train_loss=0.308, val_loss=0.863]
# Epoch 2:  50%|█████     | 1/2 [00:00<00:00, 30.57it/s, v_num=0, train_loss=0.520, val_loss=0.863]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 47.20it/s, v_num=0, train_loss=0.520, val_loss=0.863]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 47.20it/s, v_num=0, train_loss=0.486, val_loss=0.863]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 246.84it/s]
#
#
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 38.07it/s, v_num=0, train_loss=0.486, val_loss=0.863]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 38.07it/s, v_num=0, train_loss=0.486, val_loss=0.863]
# Epoch 2:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.486, val_loss=0.863]
# Epoch 3:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.486, val_loss=0.863]
# Epoch 3:  50%|█████     | 1/2 [00:00<00:00, 31.12it/s, v_num=0, train_loss=0.486, val_loss=0.863]
# Epoch 3:  50%|█████     | 1/2 [00:00<00:00, 31.12it/s, v_num=0, train_loss=0.447, val_loss=0.863]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 45.53it/s, v_num=0, train_loss=0.447, val_loss=0.863]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 45.53it/s, v_num=0, train_loss=0.337, val_loss=0.863]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 500.10it/s]
#
#
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 37.80it/s, v_num=0, train_loss=0.337, val_loss=0.854]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 37.10it/s, v_num=0, train_loss=0.337, val_loss=0.854]
# Epoch 3:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.337, val_loss=0.854]
# Epoch 4:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.337, val_loss=0.854]
# Epoch 4:  50%|█████     | 1/2 [00:00<00:00, 25.95it/s, v_num=0, train_loss=0.337, val_loss=0.854]
# Epoch 4:  50%|█████     | 1/2 [00:00<00:00, 25.30it/s, v_num=0, train_loss=0.378, val_loss=0.854]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 39.44it/s, v_num=0, train_loss=0.378, val_loss=0.854]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 39.44it/s, v_num=0, train_loss=0.555, val_loss=0.854]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 499.26it/s]
#
#
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 34.20it/s, v_num=0, train_loss=0.555, val_loss=0.836]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 34.20it/s, v_num=0, train_loss=0.555, val_loss=0.836]
# Epoch 4:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.555, val_loss=0.836]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.555, val_loss=0.836]
# Epoch 5:  50%|█████     | 1/2 [00:00<00:00, 31.72it/s, v_num=0, train_loss=0.555, val_loss=0.836]
# Epoch 5:  50%|█████     | 1/2 [00:00<00:00, 30.75it/s, v_num=0, train_loss=0.332, val_loss=0.836]
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 46.91it/s, v_num=0, train_loss=0.332, val_loss=0.836]
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 46.91it/s, v_num=0, train_loss=0.487, val_loss=0.836]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 248.42it/s]
#
#
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 38.34it/s, v_num=0, train_loss=0.487, val_loss=0.821]
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 37.49it/s, v_num=0, train_loss=0.487, val_loss=0.821]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.487, val_loss=0.821]
# Epoch 6:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.487, val_loss=0.821]
# Epoch 6:  50%|█████     | 1/2 [00:00<00:00, 30.28it/s, v_num=0, train_loss=0.487, val_loss=0.821]
# Epoch 6:  50%|█████     | 1/2 [00:00<00:00, 30.28it/s, v_num=0, train_loss=0.351, val_loss=0.821]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 49.95it/s, v_num=0, train_loss=0.351, val_loss=0.821]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 48.74it/s, v_num=0, train_loss=0.495, val_loss=0.821]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 999.83it/s]
#
#
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 41.20it/s, v_num=0, train_loss=0.495, val_loss=0.814]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 41.20it/s, v_num=0, train_loss=0.495, val_loss=0.814]
# Epoch 6:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.495, val_loss=0.814]
# Epoch 7:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.495, val_loss=0.814]
# Epoch 7:  50%|█████     | 1/2 [00:00<00:00, 31.70it/s, v_num=0, train_loss=0.495, val_loss=0.814]
# Epoch 7:  50%|█████     | 1/2 [00:00<00:00, 30.73it/s, v_num=0, train_loss=0.338, val_loss=0.814]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 47.55it/s, v_num=0, train_loss=0.338, val_loss=0.814]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 47.55it/s, v_num=0, train_loss=0.481, val_loss=0.814]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 1000.07it/s]
#
#
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 38.41it/s, v_num=0, train_loss=0.481, val_loss=0.809]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 38.41it/s, v_num=0, train_loss=0.481, val_loss=0.809]
# Epoch 7:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.481, val_loss=0.809]
# Epoch 8:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.481, val_loss=0.809]
# Epoch 8:  50%|█████     | 1/2 [00:00<00:00, 31.73it/s, v_num=0, train_loss=0.481, val_loss=0.809]
# Epoch 8:  50%|█████     | 1/2 [00:00<00:00, 31.73it/s, v_num=0, train_loss=0.309, val_loss=0.809]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 49.35it/s, v_num=0, train_loss=0.309, val_loss=0.809]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 49.35it/s, v_num=0, train_loss=0.538, val_loss=0.809]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 500.10it/s]
#
#
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 39.97it/s, v_num=0, train_loss=0.538, val_loss=0.809]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 39.97it/s, v_num=0, train_loss=0.538, val_loss=0.809]
# Epoch 8:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.538, val_loss=0.809]
# Epoch 9:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.538, val_loss=0.809]
# Epoch 9:  50%|█████     | 1/2 [00:00<00:00, 26.88it/s, v_num=0, train_loss=0.538, val_loss=0.809]
# Epoch 9:  50%|█████     | 1/2 [00:00<00:00, 26.88it/s, v_num=0, train_loss=0.321, val_loss=0.809]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 43.70it/s, v_num=0, train_loss=0.321, val_loss=0.809]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 43.70it/s, v_num=0, train_loss=0.289, val_loss=0.809]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 992.50it/s]
#
#
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 37.70it/s, v_num=0, train_loss=0.289, val_loss=0.808]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 36.88it/s, v_num=0, train_loss=0.289, val_loss=0.808]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 25.41it/s, v_num=0, train_loss=0.289, val_loss=0.808]
#
# Predicting: |          | 0/? [00:00<?, ?it/s]
# Predicting:   0%|          | 0/1 [00:00<?, ?it/s]
# Predicting DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 318.76it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 318.76it/s]
# Entire Test Set results: {'entire_test/mse': 20.44126385226305}
#
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking:   0%|          | 0/1 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 221.77it/s]
#
#
# Training: |          | 0/? [00:00<?, ?it/s]
# Training:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 0:  50%|█████     | 1/2 [00:00<00:00, 28.05it/s]
# Epoch 0:  50%|█████     | 1/2 [00:00<00:00, 28.05it/s, v_num=0, train_loss=0.989]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 43.15it/s, v_num=0, train_loss=0.989]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 43.15it/s, v_num=0, train_loss=0.725]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 499.80it/s]
#
#
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 35.80it/s, v_num=0, train_loss=0.725, val_loss=0.841]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 35.17it/s, v_num=0, train_loss=0.725, val_loss=0.841]
# Epoch 0:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.725, val_loss=0.841]
# Epoch 1:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.725, val_loss=0.841]
# Epoch 1:  50%|█████     | 1/2 [00:00<00:00, 27.34it/s, v_num=0, train_loss=0.725, val_loss=0.841]
# Epoch 1:  50%|█████     | 1/2 [00:00<00:00, 27.34it/s, v_num=0, train_loss=0.658, val_loss=0.841]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 43.39it/s, v_num=0, train_loss=0.658, val_loss=0.841]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 43.39it/s, v_num=0, train_loss=0.439, val_loss=0.841]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 311.87it/s]
#
#
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 35.53it/s, v_num=0, train_loss=0.439, val_loss=0.808]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 35.53it/s, v_num=0, train_loss=0.439, val_loss=0.808]
# Epoch 1:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.439, val_loss=0.808]
# Epoch 2:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.439, val_loss=0.808]
# Epoch 2:  50%|█████     | 1/2 [00:00<00:00, 29.32it/s, v_num=0, train_loss=0.439, val_loss=0.808]
# Epoch 2:  50%|█████     | 1/2 [00:00<00:00, 29.32it/s, v_num=0, train_loss=0.466, val_loss=0.808]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 43.79it/s, v_num=0, train_loss=0.466, val_loss=0.808]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 43.79it/s, v_num=0, train_loss=0.800, val_loss=0.808]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 498.73it/s]
#
#
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 37.84it/s, v_num=0, train_loss=0.800, val_loss=0.789]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 37.14it/s, v_num=0, train_loss=0.800, val_loss=0.789]
# Epoch 2:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.800, val_loss=0.789]
# Epoch 3:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.800, val_loss=0.789]
# Epoch 3:  50%|█████     | 1/2 [00:00<00:00, 29.82it/s, v_num=0, train_loss=0.800, val_loss=0.789]
# Epoch 3:  50%|█████     | 1/2 [00:00<00:00, 29.82it/s, v_num=0, train_loss=0.445, val_loss=0.789]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 45.92it/s, v_num=0, train_loss=0.445, val_loss=0.789]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 45.92it/s, v_num=0, train_loss=0.246, val_loss=0.789]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 662.61it/s]
#
#
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 38.42it/s, v_num=0, train_loss=0.246, val_loss=0.780]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 38.42it/s, v_num=0, train_loss=0.246, val_loss=0.780]
# Epoch 3:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.246, val_loss=0.780]
# Epoch 4:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.246, val_loss=0.780]
# Epoch 4:  50%|█████     | 1/2 [00:00<00:00, 27.86it/s, v_num=0, train_loss=0.246, val_loss=0.780]
# Epoch 4:  50%|█████     | 1/2 [00:00<00:00, 27.86it/s, v_num=0, train_loss=0.453, val_loss=0.780]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 43.10it/s, v_num=0, train_loss=0.453, val_loss=0.780]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 43.10it/s, v_num=0, train_loss=0.554, val_loss=0.780]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 500.81it/s]
#
#
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 36.43it/s, v_num=0, train_loss=0.554, val_loss=0.777]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 36.43it/s, v_num=0, train_loss=0.554, val_loss=0.777]
# Epoch 4:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.554, val_loss=0.777]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.554, val_loss=0.777]
# Epoch 5:  50%|█████     | 1/2 [00:00<00:00, 28.00it/s, v_num=0, train_loss=0.554, val_loss=0.777]
# Epoch 5:  50%|█████     | 1/2 [00:00<00:00, 28.00it/s, v_num=0, train_loss=0.427, val_loss=0.777]
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 43.66it/s, v_num=0, train_loss=0.427, val_loss=0.777]
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 42.68it/s, v_num=0, train_loss=0.235, val_loss=0.777]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 285.39it/s]
#
#
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 34.66it/s, v_num=0, train_loss=0.235, val_loss=0.776]
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 34.66it/s, v_num=0, train_loss=0.235, val_loss=0.776]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.235, val_loss=0.776]
# Epoch 6:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.235, val_loss=0.776]
# Epoch 6:  50%|█████     | 1/2 [00:00<00:00, 24.37it/s, v_num=0, train_loss=0.235, val_loss=0.776]
# Epoch 6:  50%|█████     | 1/2 [00:00<00:00, 24.37it/s, v_num=0, train_loss=0.307, val_loss=0.776]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 38.46it/s, v_num=0, train_loss=0.307, val_loss=0.776]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 38.46it/s, v_num=0, train_loss=0.567, val_loss=0.776]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 499.26it/s]
#
#
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 33.61it/s, v_num=0, train_loss=0.567, val_loss=0.777]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 33.61it/s, v_num=0, train_loss=0.567, val_loss=0.777]
# Epoch 6:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.567, val_loss=0.777]
# Epoch 7:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.567, val_loss=0.777]
# Epoch 7:  50%|█████     | 1/2 [00:00<00:00, 27.85it/s, v_num=0, train_loss=0.567, val_loss=0.777]
# Epoch 7:  50%|█████     | 1/2 [00:00<00:00, 27.10it/s, v_num=0, train_loss=0.339, val_loss=0.777]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 40.48it/s, v_num=0, train_loss=0.339, val_loss=0.777]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 40.48it/s, v_num=0, train_loss=0.224, val_loss=0.777]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 497.43it/s]
#
#
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 34.82it/s, v_num=0, train_loss=0.224, val_loss=0.777]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 34.82it/s, v_num=0, train_loss=0.224, val_loss=0.777]
# Epoch 7:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.224, val_loss=0.777]
# Epoch 8:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.224, val_loss=0.777]
# Epoch 8:  50%|█████     | 1/2 [00:00<00:00, 24.73it/s, v_num=0, train_loss=0.224, val_loss=0.777]
# Epoch 8:  50%|█████     | 1/2 [00:00<00:00, 24.73it/s, v_num=0, train_loss=0.319, val_loss=0.777]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 40.04it/s, v_num=0, train_loss=0.319, val_loss=0.777]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 39.25it/s, v_num=0, train_loss=0.352, val_loss=0.777]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 317.82it/s]
#
#
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 32.46it/s, v_num=0, train_loss=0.352, val_loss=0.777]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 31.71it/s, v_num=0, train_loss=0.352, val_loss=0.777]
# Epoch 8:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.352, val_loss=0.777]
# Epoch 9:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.352, val_loss=0.777]
# Epoch 9:  50%|█████     | 1/2 [00:00<00:00, 19.16it/s, v_num=0, train_loss=0.352, val_loss=0.777]
# Epoch 9:  50%|█████     | 1/2 [00:00<00:00, 19.16it/s, v_num=0, train_loss=0.293, val_loss=0.777]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 31.89it/s, v_num=0, train_loss=0.293, val_loss=0.777]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 31.39it/s, v_num=0, train_loss=0.398, val_loss=0.777]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 221.99it/s]
#
#
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 26.76it/s, v_num=0, train_loss=0.398, val_loss=0.778]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 26.41it/s, v_num=0, train_loss=0.398, val_loss=0.778]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 22.28it/s, v_num=0, train_loss=0.398, val_loss=0.778]
#
# Predicting: |          | 0/? [00:00<?, ?it/s]
# Predicting:   0%|          | 0/1 [00:00<?, ?it/s]
# Predicting DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 333.41it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 333.41it/s]
# Entire Test Set results: {'entire_test/mse': 21.506011704752332}
#
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking:   0%|          | 0/1 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 221.17it/s]
#
#
# Training: |          | 0/? [00:00<?, ?it/s]
# Training:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 0:  50%|█████     | 1/2 [00:00<00:00, 21.68it/s]
# Epoch 0:  50%|█████     | 1/2 [00:00<00:00, 21.68it/s, v_num=0, train_loss=1.010]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 36.12it/s, v_num=0, train_loss=1.010]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 36.12it/s, v_num=0, train_loss=1.060]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 397.45it/s]
#
#
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 31.54it/s, v_num=0, train_loss=1.060, val_loss=0.833]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 31.05it/s, v_num=0, train_loss=1.060, val_loss=0.833]
# Epoch 0:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=1.060, val_loss=0.833]
# Epoch 1:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=1.060, val_loss=0.833]
# Epoch 1:  50%|█████     | 1/2 [00:00<00:00, 31.23it/s, v_num=0, train_loss=1.060, val_loss=0.833]
# Epoch 1:  50%|█████     | 1/2 [00:00<00:00, 31.23it/s, v_num=0, train_loss=0.636, val_loss=0.833]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 46.55it/s, v_num=0, train_loss=0.636, val_loss=0.833]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 46.55it/s, v_num=0, train_loss=0.987, val_loss=0.833]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 415.44it/s]
#
#
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 39.08it/s, v_num=0, train_loss=0.987, val_loss=0.816]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 39.08it/s, v_num=0, train_loss=0.987, val_loss=0.816]
# Epoch 1:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.987, val_loss=0.816]
# Epoch 2:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.987, val_loss=0.816]
# Epoch 2:  50%|█████     | 1/2 [00:00<00:00, 27.88it/s, v_num=0, train_loss=0.987, val_loss=0.816]
# Epoch 2:  50%|█████     | 1/2 [00:00<00:00, 27.88it/s, v_num=0, train_loss=0.527, val_loss=0.816]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 43.69it/s, v_num=0, train_loss=0.527, val_loss=0.816]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 43.69it/s, v_num=0, train_loss=0.584, val_loss=0.816]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 548.63it/s]
#
#
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 36.62it/s, v_num=0, train_loss=0.584, val_loss=0.804]
# Epoch 2: 100%|██████████| 2/2 [00:00<00:00, 35.95it/s, v_num=0, train_loss=0.584, val_loss=0.804]
# Epoch 2:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.584, val_loss=0.804]
# Epoch 3:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.584, val_loss=0.804]
# Epoch 3:  50%|█████     | 1/2 [00:00<00:00, 31.73it/s, v_num=0, train_loss=0.584, val_loss=0.804]
# Epoch 3:  50%|█████     | 1/2 [00:00<00:00, 31.73it/s, v_num=0, train_loss=0.523, val_loss=0.804]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 48.74it/s, v_num=0, train_loss=0.523, val_loss=0.804]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 48.74it/s, v_num=0, train_loss=0.430, val_loss=0.804]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 499.08it/s]
#
#
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 40.38it/s, v_num=0, train_loss=0.430, val_loss=0.795]
# Epoch 3: 100%|██████████| 2/2 [00:00<00:00, 40.38it/s, v_num=0, train_loss=0.430, val_loss=0.795]
# Epoch 3:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.430, val_loss=0.795]
# Epoch 4:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.430, val_loss=0.795]
# Epoch 4:  50%|█████     | 1/2 [00:00<00:00, 33.88it/s, v_num=0, train_loss=0.430, val_loss=0.795]
# Epoch 4:  50%|█████     | 1/2 [00:00<00:00, 32.77it/s, v_num=0, train_loss=0.492, val_loss=0.795]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 50.85it/s, v_num=0, train_loss=0.492, val_loss=0.795]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 50.85it/s, v_num=0, train_loss=0.322, val_loss=0.795]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 487.54it/s]
#
#
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 42.65it/s, v_num=0, train_loss=0.322, val_loss=0.790]
# Epoch 4: 100%|██████████| 2/2 [00:00<00:00, 42.65it/s, v_num=0, train_loss=0.322, val_loss=0.790]
# Epoch 4:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.322, val_loss=0.790]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.322, val_loss=0.790]
# Epoch 5:  50%|█████     | 1/2 [00:00<00:00, 30.50it/s, v_num=0, train_loss=0.322, val_loss=0.790]
# Epoch 5:  50%|█████     | 1/2 [00:00<00:00, 30.50it/s, v_num=0, train_loss=0.428, val_loss=0.790]
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 45.16it/s, v_num=0, train_loss=0.428, val_loss=0.790]
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 45.16it/s, v_num=0, train_loss=0.513, val_loss=0.790]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 499.86it/s]
#
#
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 37.17it/s, v_num=0, train_loss=0.513, val_loss=0.788]
# Epoch 5: 100%|██████████| 2/2 [00:00<00:00, 36.49it/s, v_num=0, train_loss=0.513, val_loss=0.788]
# Epoch 5:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.513, val_loss=0.788]
# Epoch 6:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.513, val_loss=0.788]
# Epoch 6:  50%|█████     | 1/2 [00:00<00:00, 28.04it/s, v_num=0, train_loss=0.513, val_loss=0.788]
# Epoch 6:  50%|█████     | 1/2 [00:00<00:00, 27.27it/s, v_num=0, train_loss=0.376, val_loss=0.788]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 43.30it/s, v_num=0, train_loss=0.376, val_loss=0.788]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 43.30it/s, v_num=0, train_loss=0.533, val_loss=0.788]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 398.40it/s]
#
#
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 37.24it/s, v_num=0, train_loss=0.533, val_loss=0.788]
# Epoch 6: 100%|██████████| 2/2 [00:00<00:00, 37.24it/s, v_num=0, train_loss=0.533, val_loss=0.788]
# Epoch 6:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.533, val_loss=0.788]
# Epoch 7:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.533, val_loss=0.788]
# Epoch 7:  50%|█████     | 1/2 [00:00<00:00, 27.36it/s, v_num=0, train_loss=0.533, val_loss=0.788]
# Epoch 7:  50%|█████     | 1/2 [00:00<00:00, 26.63it/s, v_num=0, train_loss=0.371, val_loss=0.788]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 41.61it/s, v_num=0, train_loss=0.371, val_loss=0.788]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 40.76it/s, v_num=0, train_loss=0.249, val_loss=0.788]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 480.06it/s]
#
#
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 35.06it/s, v_num=0, train_loss=0.249, val_loss=0.788]
# Epoch 7: 100%|██████████| 2/2 [00:00<00:00, 34.18it/s, v_num=0, train_loss=0.249, val_loss=0.788]
# Epoch 7:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.249, val_loss=0.788]
# Epoch 8:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.249, val_loss=0.788]
# Epoch 8:  50%|█████     | 1/2 [00:00<00:00, 22.97it/s, v_num=0, train_loss=0.249, val_loss=0.788]
# Epoch 8:  50%|█████     | 1/2 [00:00<00:00, 22.97it/s, v_num=0, train_loss=0.347, val_loss=0.788]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 33.87it/s, v_num=0, train_loss=0.347, val_loss=0.788]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 33.87it/s, v_num=0, train_loss=0.306, val_loss=0.788]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 333.46it/s]
#
#
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 27.95it/s, v_num=0, train_loss=0.306, val_loss=0.788]
# Epoch 8: 100%|██████████| 2/2 [00:00<00:00, 27.56it/s, v_num=0, train_loss=0.306, val_loss=0.788]
# Epoch 8:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.306, val_loss=0.788]
# Epoch 9:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.306, val_loss=0.788]
# Epoch 9:  50%|█████     | 1/2 [00:00<00:00, 19.78it/s, v_num=0, train_loss=0.306, val_loss=0.788]
# Epoch 9:  50%|█████     | 1/2 [00:00<00:00, 19.78it/s, v_num=0, train_loss=0.346, val_loss=0.788]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 32.76it/s, v_num=0, train_loss=0.346, val_loss=0.788]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 32.23it/s, v_num=0, train_loss=0.194, val_loss=0.788]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 284.98it/s]
#
#
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 27.19it/s, v_num=0, train_loss=0.194, val_loss=0.787]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 27.19it/s, v_num=0, train_loss=0.194, val_loss=0.787]
# Epoch 9: 100%|██████████| 2/2 [00:00<00:00, 18.00it/s, v_num=0, train_loss=0.194, val_loss=0.787]
#
# Predicting: |          | 0/? [00:00<?, ?it/s]
# Predicting:   0%|          | 0/1 [00:00<?, ?it/s]
# Predicting DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 105.17it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 95.17it/s]
# Entire Test Set results: {'entire_test/mse': 20.66660425859032}
#
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking:   0%|          | 0/1 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 285.23it/s]
#
#
# Training: |          | 0/? [00:00<?, ?it/s]
# Training:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch 0:  50%|█████     | 1/2 [00:00<00:00, 27.16it/s]
# Epoch 0:  50%|█████     | 1/2 [00:00<00:00, 26.44it/s, v_num=0, train_loss=1.130]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 44.63it/s, v_num=0, train_loss=1.130]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 43.18it/s, v_num=0, train_loss=0.536]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 462.85it/s]
#
#
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 37.09it/s, v_num=0, train_loss=0.536, val_loss=0.847]
# Epoch 0: 100%|██████████| 2/2 [00:00<00:00, 37.09it/s, v_num=0, train_loss=0.536, val_loss=0.847]
# Epoch 0:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.536, val_loss=0.847]
# Epoch 1:   0%|          | 0/2 [00:00<?, ?it/s, v_num=0, train_loss=0.536, val_loss=0.847]
# Epoch 1:  50%|█████     | 1/2 [00:00<00:00, 28.31it/s, v_num=0, train_loss=0.536, val_loss=0.847]
# Epoch 1:  50%|█████     | 1/2 [00:00<00:00, 28.31it/s, v_num=0, train_loss=0.668, val_loss=0.847]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 43.08it/s, v_num=0, train_loss=0.668, val_loss=0.847]
# Epoch 1: 100%|██████████| 2/2 [00:00<00:00, 43.08it/s, v_num=0, train_loss=0.420, val_loss=0.847]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# ...
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\utilities\parsing.py:199: Attribute 'graph_transform' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['graph_transform'])`.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\utilities\parsing.py:199: Attribute 'output_transform' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['output_transform'])`.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: chemprop_training\071524_chemprop\2024-11-14T14-20-06\model_1\trainer_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loading `train_dataloader` to estimate number of stepping batches.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\loops\fit_loop.py:298: The number of training batches (2) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#
#   | Name            | Type               | Params
# -------------------------------------------------------
# 0 | message_passing | BondMessagePassing | 318 K
# 1 | agg             | MeanAggregation    | 0
# 2 | bn              | BatchNorm1d        | 600
# 3 | predictor       | RegressionFFN      | 91.2 K
# 4 | X_d_transform   | Identity           | 0
# -------------------------------------------------------
# 409 K     Trainable params
# 0         Non-trainable params
# 409 K     Total params
# 1.639     Total estimated model params size (MB)
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=10` reached.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\checkpoint_connector.py:145: `.predict(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `.predict(ckpt_path='best')` to use the best model or `.predict(ckpt_path='last')` to use the last model. If you pass a value, this warning will be silenced.
# Restoring states from the checkpoint path at C:\Users\hsk81\OneDrive - Virginia Tech\Desktop\area-per-molecule\code\ChemProp\summary_file\chemprop_training\071524_chemprop\2024-11-14T14-20-06\model_1\checkpoints\best-epoch=9-val_loss=0.81.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at C:\Users\hsk81\OneDrive - Virginia Tech\Desktop\area-per-molecule\code\ChemProp\summary_file\chemprop_training\071524_chemprop\2024-11-14T14-20-06\model_1\checkpoints\best-epoch=9-val_loss=0.81.ckpt
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\utilities\parsing.py:199: Attribute 'graph_transform' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['graph_transform'])`.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\utilities\parsing.py:199: Attribute 'output_transform' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['output_transform'])`.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: chemprop_training\071524_chemprop\2024-11-14T14-20-06\model_2\trainer_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loading `train_dataloader` to estimate number of stepping batches.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\loops\fit_loop.py:298: The number of training batches (2) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#
#   | Name            | Type               | Params
# -------------------------------------------------------
# 0 | message_passing | BondMessagePassing | 318 K
# 1 | agg             | MeanAggregation    | 0
# 2 | bn              | BatchNorm1d        | 600
# 3 | predictor       | RegressionFFN      | 91.2 K
# 4 | X_d_transform   | Identity           | 0
# -------------------------------------------------------
# 409 K     Trainable params
# 0         Non-trainable params
# 409 K     Total params
# 1.639     Total estimated model params size (MB)
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=10` reached.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\checkpoint_connector.py:145: `.predict(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `.predict(ckpt_path='best')` to use the best model or `.predict(ckpt_path='last')` to use the last model. If you pass a value, this warning will be silenced.
# Restoring states from the checkpoint path at C:\Users\hsk81\OneDrive - Virginia Tech\Desktop\area-per-molecule\code\ChemProp\summary_file\chemprop_training\071524_chemprop\2024-11-14T14-20-06\model_2\checkpoints\best-epoch=5-val_loss=0.78.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at C:\Users\hsk81\OneDrive - Virginia Tech\Desktop\area-per-molecule\code\ChemProp\summary_file\chemprop_training\071524_chemprop\2024-11-14T14-20-06\model_2\checkpoints\best-epoch=5-val_loss=0.78.ckpt
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\utilities\parsing.py:199: Attribute 'graph_transform' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['graph_transform'])`.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\utilities\parsing.py:199: Attribute 'output_transform' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['output_transform'])`.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: chemprop_training\071524_chemprop\2024-11-14T14-20-06\model_3\trainer_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loading `train_dataloader` to estimate number of stepping batches.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\loops\fit_loop.py:298: The number of training batches (2) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#
#   | Name            | Type               | Params
# -------------------------------------------------------
# 0 | message_passing | BondMessagePassing | 318 K
# 1 | agg             | MeanAggregation    | 0
# 2 | bn              | BatchNorm1d        | 600
# 3 | predictor       | RegressionFFN      | 91.2 K
# 4 | X_d_transform   | Identity           | 0
# -------------------------------------------------------
# 409 K     Trainable params
# 0         Non-trainable params
# 409 K     Total params
# 1.639     Total estimated model params size (MB)
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=10` reached.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\checkpoint_connector.py:145: `.predict(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `.predict(ckpt_path='best')` to use the best model or `.predict(ckpt_path='last')` to use the last model. If you pass a value, this warning will be silenced.
# Restoring states from the checkpoint path at C:\Users\hsk81\OneDrive - Virginia Tech\Desktop\area-per-molecule\code\ChemProp\summary_file\chemprop_training\071524_chemprop\2024-11-14T14-20-06\model_3\checkpoints\best-epoch=9-val_loss=0.79.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at C:\Users\hsk81\OneDrive - Virginia Tech\Desktop\area-per-molecule\code\ChemProp\summary_file\chemprop_training\071524_chemprop\2024-11-14T14-20-06\model_3\checkpoints\best-epoch=9-val_loss=0.79.ckpt
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\utilities\parsing.py:199: Attribute 'graph_transform' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['graph_transform'])`.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\utilities\parsing.py:199: Attribute 'output_transform' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['output_transform'])`.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: chemprop_training\071524_chemprop\2024-11-14T14-20-06\model_4\trainer_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loading `train_dataloader` to estimate number of stepping batches.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\loops\fit_loop.py:298: The number of training batches (2) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#
#   | Name            | Type               | Params
# -------------------------------------------------------
# 0 | message_passing | BondMessagePassing | 318 K
# 1 | agg             | MeanAggregation    | 0
# 2 | bn              | BatchNorm1d        | 600
# 3 | predictor       | RegressionFFN      | 91.2 K
# 4 | X_d_transform   | Identity           | 0
# -------------------------------------------------------
# 409 K     Trainable params
# 0         Non-trainable params
# 409 K     Total params
# 1.639     Total estimated model params size (MB)
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=10` reached.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\checkpoint_connector.py:145: `.predict(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `.predict(ckpt_path='best')` to use the best model or `.predict(ckpt_path='last')` to use the last model. If you pass a value, this warning will be silenced.
# Restoring states from the checkpoint path at C:\Users\hsk81\OneDrive - Virginia Tech\Desktop\area-per-molecule\code\ChemProp\summary_file\chemprop_training\071524_chemprop\2024-11-14T14-20-06\model_4\checkpoints\best-epoch=9-val_loss=0.76.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at C:\Users\hsk81\OneDrive - Virginia Tech\Desktop\area-per-molecule\code\ChemProp\summary_file\chemprop_training\071524_chemprop\2024-11-14T14-20-06\model_4\checkpoints\best-epoch=9-val_loss=0.76.ckpt
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:441: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\utilities\parsing.py:199: Attribute 'graph_transform' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['graph_transform'])`.
# C:\Users\hsk81\miniconda3\envs\env_area_per_molecule\Lib\site-packages\lightning\pytorch\utilities\parsing.py:199: Attribute 'output_transform' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['output_transform'])`.

# %%
# file scan
import os

def scan_files_in_folders(folders):
    models = []
    for folder in folders:
        print(f"Scanning folder: {folder}")
        for root, _, files in os.walk(folder):
            for file in files:
                if 'last' in file:
                    print(os.path.join(root, file))
                    models.append(os.path.join(root, file))
    return models

# List of folders to scan
folders_to_scan = [
    'chemprop_training/071524_chemprop/2024-11-14T14-20-06'
    # Add more folders as needed
    # 'chemprop_training/062524_chemprop_addon_modifiedF/2024-07-03T11-28-26_pure'
]

models = scan_files_in_folders(folders_to_scan)
# chemprop_training/061324_mydata_chemprop\2024-06-13T23-02-16\model_0\checkpoints\best-epoch=177-val_loss=0.12.ckpt
# chemprop_training/061324_mydata_chemprop\2024-06-14T00-54-13\model_0\checkpoints\best-epoch=164-val_loss=0.12.ckpt
# Out:
# Scanning folder: chemprop_training/071524_chemprop/2024-11-14T14-20-06
# chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_0\checkpoints\last.ckpt
# chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_1\checkpoints\last.ckpt
# chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_2\checkpoints\last.ckpt
# chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_3\checkpoints\last.ckpt
# chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_4\checkpoints\last.ckpt

# %%
# prediction (automated)
test_csv = 'smiles.csv'
xlsx = 'data_prediction.xlsx'
import subprocess
import pandas as pd
import numpy as np
for idx, model in enumerate(models):
    ########################## chemprop predict ###################################
    print(f'predict: {model}')
    command = f"chemprop predict --test-path {test_csv} --model-path {model}" #--atom-features-path MDFeatureGen/070124_partialcharge_sigma_epsilon.npz --descriptors-path MDFeatureGen/070224_surface_area_head_tail.npz"
    print(command)
    subprocess.run(command, shell=True)
    ########################## end ###################################
    
    # read pred_csv
    df_pred = pd.read_csv(test_csv.split('.')[0]+'_preds_0.csv')
    # rename the columns
    pred_0 = np.mean(df_pred['pred_0']) # supposed to be 1e-6 order
    pred_1 = np.mean(df_pred['pred_1']) # supposed to be > 0
    pred_2 = np.mean(df_pred['pred_2']) # supposed to be < 0
    rename=[]
    for pred in [pred_0, pred_1, pred_2]:
        if pred < 1e-4 and pred>0:
            rename.append('pred_0')
            continue
        if pred > 0 and pred > 1e-4 :
            rename.append('pred_1')
            continue
        if pred < 0 :
            rename.append('pred_2')
            continue
    df_pred = df_pred.rename(columns={'0':'smiles','pred_0': rename[0], 'pred_1': rename[1], 'pred_2': rename[2]})
    
    # add to xlsx file
    df_xlsx =  pd.read_excel(xlsx)
    df_xlsx['pred_0_m'+str(idx)]=df_pred['pred_0']
    df_xlsx['pred_1_m'+str(idx)]=df_pred['pred_1']
    df_xlsx['pred_2_m'+str(idx)]=df_pred['pred_2']
    # output
    # df_xlsx.to_excel(xlsx.split('.')[0]+'_update.xlsx')
    df_xlsx.to_excel(xlsx,index=False)
# Out:
# predict: chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_0\checkpoints\last.ckpt
# chemprop predict --test-path smiles.csv --model-path chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_0\checkpoints\last.ckpt
# predict: chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_1\checkpoints\last.ckpt
# chemprop predict --test-path smiles.csv --model-path chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_1\checkpoints\last.ckpt
# predict: chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_2\checkpoints\last.ckpt
# chemprop predict --test-path smiles.csv --model-path chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_2\checkpoints\last.ckpt
# predict: chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_3\checkpoints\last.ckpt
# chemprop predict --test-path smiles.csv --model-path chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_3\checkpoints\last.ckpt
# predict: chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_4\checkpoints\last.ckpt
# chemprop predict --test-path smiles.csv --model-path chemprop_training/071524_chemprop/2024-11-14T14-20-06\model_4\checkpoints\last.ckpt

# %%
# metrics
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

df = pd.read_excel("071524_chemprop_gammacmc_realgammamaxpure.xlsx")
def parityplot(y_true,y_pred,color,label,ax):
    # Calculate R²
    r2 = r2_score(y_true, y_pred)
    print(f'R-squared: {r2}')

    # Calculate RMSE
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    print(f'RMSE: {rmse}')

    # Calculate MAE
    mae = mean_absolute_error(y_true, y_pred)
    print(f'MAE: {mae}')

    ax.scatter(y_true,y_pred,color=color,label=label)
    #if label=='test':
    # for i, (true, pred) in enumerate(zip(y_true, y_pred)):
    #     plt.annotate(f'{i}', (true, pred), textcoords="offset points", xytext=(5,5), ha='center')

    ax.set_xlabel('y_true')
    ax.set_ylabel('y_pred')


# df = pd.read_csv('061224_mydata_chemprop_preds_0.csv')
df_train = df[df['test']!=True]
df_test = df[df['test']==True]

fig, ax = plt.subplots(1,3,figsize=(18,5))
#'SurfaceExcess'
print('SurfaceExcess')
print('train')
y_true = df_train['SurfaceExcess (mol/m2)'].to_numpy() 
y_pred = df_train['pred_0'].to_numpy()
parityplot(y_true*1e6,y_pred*1e6,'k','train',ax[0])
print('test')
y_true = df_test['SurfaceExcess (mol/m2)'].to_numpy()
y_pred = df_test['pred_0'].to_numpy()
parityplot(y_true*1e6,y_pred*1e6,'r','test',ax[0])
ax[0].plot([2,12],[2,12],'--k')

ax[0].legend()
ax[0].set_xlabel(r'Experimental $\Gamma_{max}\times 10^6$ (mol/m$^2$)',fontsize=16)
ax[0].set_ylabel(r'Predicted $\Gamma_{max}\times 10^6$ (mol/m$^2$)',fontsize=16)

# gamma_cmc
print('gamma CMC')
print('train')
df_train_CMC = df_train.dropna(subset=['Gamma_cmc (mN/m)'])
df_test_CMC = df_test.dropna(subset=['Gamma_cmc (mN/m)'])
y_true = df_train_CMC['Gamma_cmc (mN/m)'].to_numpy()
y_pred = df_train_CMC['pred_1'].to_numpy()
parityplot(y_true,y_pred,'k','train',ax[1])
print('test')
y_true = df_test_CMC['Gamma_cmc (mN/m)'].to_numpy()
y_pred = df_test_CMC['pred_1'].to_numpy()
parityplot(y_true,y_pred,'r','test',ax[1])
ax[1].plot([10,50],[10,50],'--k')
# ax[2].set_title('logCMC')
ax[1].set_xlabel(r'Experimental $\gamma_{CMC}$ (mN/m)',fontsize=16)
ax[1].set_ylabel(r'Predicted $\gamma_{CMC}$ (mN/m)',fontsize=16)

# LogCMC
print('LogCMC')
print('train')
df_train_CMC = df_train.dropna(subset=['LogCMC (M)'])
df_test_CMC = df_test.dropna(subset=['LogCMC (M)'])
y_true = df_train_CMC['LogCMC (M)'].to_numpy()
y_pred = df_train_CMC['pred_2'].to_numpy()
parityplot(y_true,y_pred,'k','train',ax[2])
print('test')
y_true = df_test_CMC['LogCMC (M)'].to_numpy()
y_pred = df_test_CMC['pred_2'].to_numpy()
parityplot(y_true,y_pred,'r','test',ax[2])
ax[2].plot([-5,-1],[-5,-1],'--k')
# ax[2].set_title('logCMC')
ax[2].set_xlabel('Experimental logCMC (M)',fontsize=16)
ax[2].set_ylabel('Predicted logCMC (M)',fontsize=16)
# Out:
# SurfaceExcess
# train
# R-squared: 0.9368489541608249
# RMSE: 0.4919463668102335
# MAE: 0.2893806131342768
# test
# R-squared: 0.8163847198515762
# RMSE: 1.078263369568209
# MAE: 0.7285297230287249
# gamma CMC
# train
# R-squared: 0.9464504881656658
# RMSE: 1.715903336206694
# MAE: 0.9193281561534412
# test
# R-squared: 0.9037022543266601
# RMSE: 2.6399170154500795
# MAE: 2.0859106823341653
# LogCMC
# train
# R-squared: 0.9518208139159595
# RMSE: 0.20695377084194114
# MAE: 0.13885346689327135
# test
# R-squared: 0.9034522768426992
# RMSE: 0.28014192474197547
# MAE: 0.20722859357754023
# Text(0, 0.5, 'Predicted logCMC (M)')
